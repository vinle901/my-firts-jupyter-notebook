# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
#  My name is **Vincent**
#  I want to be a ML/AI engineer

# %% [markdown]
# *I'm interested in Data Science because I can use many different tools to built some awesome machine learning models that are useful in real life*

# %% [markdown]
# ### My code in cell 5 must be executed and display an outcome

# %%
25*17-15
# Out:
# 410

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - 2020\. A disastrous year
# - 2022\. It is better now with no Corona virus

# %% [markdown]
# Road Map to became ML/ML engineer
# 1. Learn Data Science
# 2. Learn Math, especially Linear Algebra and Calculus
# 3. Learning Machine Learning
# 4. Deep Learning
# 5. AWS
# 6. Practical AWS

# %% [markdown]
# My favorite websites to learn are [Coursera](https://www.coursera.org/) and [DeepLearning.Ai](https://www.deeplearning.ai/)

# %% [markdown]
# I really to eat seafood ![seafood](attachment:cfb62e59-b579-488c-bada-7bfc5f19f298.jpg)

# %% [markdown]
# Want to write like this, choose `markdown` on the top of jupyter notebook.

# %% [markdown]
# Elon Musk just tweeted
# >Twitter is alive
# >
# >Twitter is fun

# %% [markdown]
# People said that ~~Twitter will be dead.~~ However, it is still up and running perfectly fine

# %% [markdown]
# My choice for news updating:
# | Twitter | Facebook |
# | :-----: | :------: |
# |1st choice| 2nd choice|
